# %% [markdown]
# Joao Luiz Pacher
#
# # AvaliacaoFinal_ECD_AD

# %% [markdown]
# ![q3.1_1.png](attachment:q3.1_1.png)

# %% [markdown]
# ![q3.1_2.png](attachment:q3.1_2.png)

# %% [markdown]
# ![q3.1_3.png](attachment:q3.1_3.png)

# %% [markdown]
# ![q3.1_4.png](attachment:q3.1_4.png)

# %% [markdown]
# ![q3.1_5.png](attachment:q3.1_5.png)

# %% [markdown]
# ![q3.1_6.png](attachment:q3.1_6.png)
